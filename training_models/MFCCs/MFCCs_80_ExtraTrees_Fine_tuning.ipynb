# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\tunne\anaconda3\envs\tf\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\tunne\anaconda3\envs\tf\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# C:\Users\tunne\anaconda3\envs\tf\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-246-g3d31191b-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
queen_train_path = "../../feature_extraction/MFCCs_80_features/train/train_queen.npy"
queenless_train_path = "../../feature_extraction/MFCCs_80_features/train/train_queenless.npy"
queen_test_path = "../../feature_extraction/MFCCs_80_features/test/train_queen.npy"
queenless_test_path = "../../feature_extraction/MFCCs_80_features/test/train_queenless.npy"
queen_val_path = "../../feature_extraction/MFCCs_80_features/val/train_queen.npy"
queenless_val_path = "../../feature_extraction/MFCCs_80_features/val/train_queenless.npy"

# %%
queen_train = np.load(queen_train_path)
queenless_train = np.load(queenless_train_path)
queen_test = np.load(queen_test_path)
queenless_test = np.load(queenless_test_path)
queen_val = np.load(queen_val_path)
queenless_val = np.load(queenless_val_path)

# %%
train_label = pd.DataFrame(np.hstack([[0]*7000, [1]*7000]).T, columns=['labels'])

# %%
train_data = pd.DataFrame(np.vstack([queen_train, queenless_train]))

# %%
train_data
# Out:
#                0           1          2          3          4         5   \
# 0     -531.931335  136.621933  45.603500  19.686640   6.475194  6.768497
# 1     -536.993347  138.456238  34.898472  20.860229   4.066461  3.119111
# 2     -525.730591  136.192719  36.625347  23.067327   0.258045  4.746896
# 3     -540.449829  139.705780  29.665409  21.128056   3.132750  0.994988
# 4     -543.696594  144.002136  36.112610  24.168007   2.962288  3.031038
# ...           ...         ...        ...        ...        ...       ...
# 13995 -586.455139  137.282516  34.373566  17.421253  10.941988  4.078198
# 13996 -572.707092  143.127991  32.171494  18.097290   9.731588  5.532512
# 13997 -579.057922  134.726349  32.156475  19.218019   5.755665  3.477601
# 13998 -578.548889  141.396133  31.506187  20.068113   6.832242  3.192559
# 13999 -584.915710  136.170990  31.396416  13.880579   5.610675  1.289348
#
#               6         7         8         9   ...        70        71  \
# 0      -0.932306  6.658151  3.660365  2.098238  ...  3.410441  3.068254
# 1      -2.870780  0.477826  3.070781  0.220865  ...  3.271066  3.057924
# 2      -0.178224  2.476325  7.398917  3.634185  ...  2.569722  2.521067
# 3       0.255035 -0.820775  1.864982  0.350622  ...  3.424932  2.889518
# 4      -5.003596  1.735093  2.667939  1.482007  ...  2.344167  3.222942
# ...          ...       ...       ...       ...  ...       ...       ...
# 13995  11.242457  5.941251  6.012725  8.022065  ...  2.428052  2.559160
# 13996   8.742662  3.005665  5.201865  7.527236  ...  2.768167  2.137187
# 13997  12.935046  6.404186  5.639282  6.843115  ...  2.286288  3.401324
# 13998  11.349093  4.352320  4.009240  5.281808  ...  2.726443  2.538073
# 13999  10.359846  7.912798  7.798289  7.257982  ...  2.800722  2.659052
#
#              72        73        74        75        76        77        78  \
# 0      3.461446  2.733752  2.617498  2.545141  3.265490  2.939814  3.251054
# 1      2.934288  2.283246  2.528649  3.761013  3.405852  3.222660  2.804340
# 2      2.660564  3.227906  2.621328  2.251341  2.990477  3.052036  2.337557
# 3      2.459073  2.296302  2.437574  3.083648  2.754676  2.309684  2.791369
# 4      2.953240  2.791287  2.718980  2.942434  2.700898  2.942176  2.915053
# ...         ...       ...       ...       ...       ...       ...       ...
# 13995  2.407419  3.277859  2.843850  2.667268  2.398551  2.329866  2.560516
# 13996  3.072467  2.713317  2.586028  3.205523  3.542013  2.731712  2.763573
# 13997  2.976722  2.437173  2.736468  2.637976  2.689160  2.406368  2.608299
# 13998  2.842417  2.398781  3.491852  2.933051  2.796699  2.359412  2.553164
# 13999  2.569515  2.672035  2.247468  2.508451  2.338107  3.018700  2.884820
#
#              79
# 0      2.363111
# 1      2.501446
# 2      3.078192
# 3      2.983374
# 4      2.179448
# ...         ...
# 13995  2.335296
# 13996  2.462618
# 13997  2.571860
# 13998  2.986884
# 13999  2.603256
#
# [14000 rows x 80 columns]

# %%
queenless_test.shape
# Out:
# (2000, 80)

# %%
test_label = pd.DataFrame(np.hstack([[0]*3000, [1]*3000]).T, columns=['labels'])
test_data = pd.DataFrame(np.vstack([queen_test, queen_val, queenless_test, queenless_val]))

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, BaggingClassifier

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(train_data)

# %%
X_test_scaled = scaler.transform(test_data)

# %%
X_scaled
# Out:
# array([[-0.20656753, -1.05254159,  1.80653149, ...,  0.70874456,
#          1.59604135, -0.75493088],
#        [-0.28666657, -0.89583887,  0.62970205, ...,  1.44871751,
#          0.40047672, -0.38207314],
#        [-0.10844967, -1.08920894,  0.81954159, ...,  1.00233595,
#         -0.84879803,  1.17243335],
#        ...,
#        [-0.95227791, -1.21447935,  0.32826777, ..., -0.686837  ,
#         -0.12419878, -0.19228823],
#        [-0.94422319, -0.64468669,  0.25678009, ..., -0.80968377,
#         -0.27175752,  0.92632872],
#        [-1.04496897, -1.09106518,  0.24471263, ...,  0.9151236 ,
#          0.61586909, -0.1076647 ]])

# %%
import time
from sklearn.model_selection import RandomizedSearchCV

t1 = time.time()
extra_trees_search={'n_estimators': [int(x) for x in np.arange(50, 126, 5)],
                    'max_features': [int(x) for x in np.arange(50, 401, 50)],
                    'min_samples_leaf':  [int(x) for x in np.arange(20, 51, 5)],
                    'min_samples_split': [int(x) for x in np.arange(15, 36, 5)],
                    }
base_model = ExtraTreesClassifier(random_state = 1337)
clf = RandomizedSearchCV(base_model, extra_trees_search, scoring='accuracy', n_iter=50, random_state=1337, verbose=3)
clf.fit(X_scaled, np.array(train_label).ravel())

clf.fit(X_scaled, np.array(train_label).ravel())
t2 = time.time()
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END max_features=50, min_samples_leaf=45, min_samples_split=15, n_estimators=50;, score=0.691 total time=   1.2s
# [CV 2/5] END max_features=50, min_samples_leaf=45, min_samples_split=15, n_estimators=50;, score=0.834 total time=   1.2s
# [CV 3/5] END max_features=50, min_samples_leaf=45, min_samples_split=15, n_estimators=50;, score=0.761 total time=   1.2s
# [CV 4/5] END max_features=50, min_samples_leaf=45, min_samples_split=15, n_estimators=50;, score=0.807 total time=   1.3s
# [CV 5/5] END max_features=50, min_samples_leaf=45, min_samples_split=15, n_estimators=50;, score=0.746 total time=   1.2s
# [CV 1/5] END max_features=400, min_samples_leaf=30, min_samples_split=30, n_estimators=90;, score=0.702 total time=   3.6s
# [CV 2/5] END max_features=400, min_samples_leaf=30, min_samples_split=30, n_estimators=90;, score=0.846 total time=   3.8s
# [CV 3/5] END max_features=400, min_samples_leaf=30, min_samples_split=30, n_estimators=90;, score=0.768 total time=   3.8s
# [CV 4/5] END max_features=400, min_samples_leaf=30, min_samples_split=30, n_estimators=90;, score=0.828 total time=   3.9s
# [CV 5/5] END max_features=400, min_samples_leaf=30, min_samples_split=30, n_estimators=90;, score=0.743 total time=   3.9s
# [CV 1/5] END max_features=100, min_samples_leaf=30, min_samples_split=15, n_estimators=65;, score=0.699 total time=   2.7s
# [CV 2/5] END max_features=100, min_samples_leaf=30, min_samples_split=15, n_estimators=65;, score=0.846 total time=   3.1s
# [CV 3/5] END max_features=100, min_samples_leaf=30, min_samples_split=15, n_estimators=65;, score=0.766 total time=   3.0s
# [CV 4/5] END max_features=100, min_samples_leaf=30, min_samples_split=15, n_estimators=65;, score=0.826 total time=   2.9s
# [CV 5/5] END max_features=100, min_samples_leaf=30, min_samples_split=15, n_estimators=65;, score=0.749 total time=   2.6s
# [CV 1/5] END max_features=50, min_samples_leaf=20, min_samples_split=20, n_estimators=70;, score=0.701 total time=   2.0s
# [CV 2/5] END max_features=50, min_samples_leaf=20, min_samples_split=20, n_estimators=70;, score=0.850 total time=   2.1s
# [CV 3/5] END max_features=50, min_samples_leaf=20, min_samples_split=20, n_estimators=70;, score=0.757 total time=   2.1s
# [CV 4/5] END max_features=50, min_samples_leaf=20, min_samples_split=20, n_estimators=70;, score=0.839 total time=   2.2s
# [CV 5/5] END max_features=50, min_samples_leaf=20, min_samples_split=20, n_estimators=70;, score=0.756 total time=   2.1s
# [CV 1/5] END max_features=350, min_samples_leaf=40, min_samples_split=15, n_estimators=105;, score=0.700 total time=   3.9s
# [CV 2/5] END max_features=350, min_samples_leaf=40, min_samples_split=15, n_estimators=105;, score=0
5] END max_features=400, min_samples_leaf=30, min_samples_split=30, n_estimators=90;, score=0.828 total time=   3.8s
# [CV 5/5] END max_features=400, min_samples_leaf=30, min_samples_split=30, n_estimators=90;, score=0.743 total time=   3.9s
# [CV 1/5] END max_features=100, min_samples_leaf=30, min_samples_split=15, n_estimators=65;, score=0.699 total time=   2.7s
# [CV 2/5] END max_features=100, min_samples_leaf=30, min_samples_split=15, n_estimators=65;, score=0.846 total time=   2.7s
# [CV 3/5] END max_features=100, min_samples_leaf=30, min_samples_split=15, n_estimators=65;, score=0.766 total time=   2.6s
# [CV 4/5] END max_features=100, min_samples_leaf=30, min_samples_split=15, n_estimators=65;, score=0.826 total time=   2.7s
# [CV 5/5] END max_features=100, min_samples_leaf=30, min_samples_split=15, n_estimators=65;, score=0.749 total time=   2.6s
# [CV 1/5] END max_features=50, min_samples_leaf=20, min_samples_split=20, n_estimators=70;, score=0.701 total time=   2.0s
# [CV 2/5] END max_features=50, min_samples_leaf=20, min_samples_split=20, n_estimators=70;, score=0.850 total time=   2.3s
# [CV 3/5] END max_features=50, min_samples_leaf=20, min_samples_split=20, n_estimators=70;, score=0.757 total time=   2.1s
# [CV 4/5] END max_features=50, min_samples_leaf=20, min_samples_split=20, n_estimators=70;, score=0.839 total time=   2.3s
# [CV 5/5] END max_features=50, min_samples_leaf=20, min_samples_split=20, n_estimators=70;, score=0.756 total time=   2.1s
# [CV 1/5] END max_features=350, min_samples_leaf=40, min_samples_split=15, n_estimators=105;, score=0.700 total time=   4.0s
# [CV 2/5] END max_features=350, min_samples_leaf=40, min_samples_split=15, n_estimators=105;, score=0.838 total time=   4.1s
# [CV 3/5] END max_features=350, min_samples_leaf=40, min_samples_split=15, n_estimators=105;, score=0.764 total time=   4.0s
# [CV 4/5] END max_features=350, min_samples_leaf=40, min_samples_split=15, n_estimators=105;, score=0.829 total time=   4.0s
# [CV 5/5] END max_features=350, min_samples_leaf=40, min_samples_split=15, n_estimators=105;, score=0.746 total time=   4.0s
# [CV 1/5] END max_features=100, min_samples_leaf=20, min_samples_split=15, n_estimators=85;, score=0.703 total time=   4.0s
# [CV 2/5] END max_features=100, min_samples_leaf=20, min_samples_split=15, n_estimators=85;, score=0.850 total time=   4.2s
# [CV 3/5] END max_features=100, min_samples_leaf=20, min_samples_split=15, n_estimators=85;, score=0.768 total time=   3.8s
# [CV 4/5] END max_features=100, min_samples_leaf=20, min_samples_split=15, n_estimators=85;, score=0.837 total time=   4.1s
# [CV 5/5] END max_features=100, min_samples_leaf=20, min_samples_split=15, n_estimators=85;, score=0.752 total time=   4.3s
# [CV 1/5] END max_features=100, min_samples_leaf=35, min_samples_split=15, n_estimators=80;, score=0.699 total time=   3.1s
# [CV 2/5] END max_features=100, min_samples_leaf=35, min_samples_split=15, n_estimators=80;, score=0.847 total time=   3.2s
# [CV 3/5] END max_features=100, min_samples_leaf=35, min_samples_split=15, n_estimators=80;, score=0.758 total time=   3.2s
# [CV 4/5] END max_features=100, min_samples_leaf=35, min_samples_split=15, n_estimators=80;, score=0.823 total time=   3.2s
# [CV 5/5] END max_features=100, min_samples_leaf=35, min_samples_split=15, n_estimators=80;, score=0.744 total time=   3.1s
# [CV 1/5] END max_features=250, min_samples_leaf=50, min_samples_split=15, n_estimators=105;, score=0.695 total time=   3.7s
# [CV 2/5] END max_features=250, min_samples_leaf=50, min_samples_split=15, n_estimators=105;, score=0.832 total time=   3.8s
# [CV 3/5] END max_features=250, min_samples_leaf=50, min_samples_split=15, n_estimators=105;, score=0.764 total time=   3.8s
# [CV 4/5] END max_features=250, min_samples_leaf=50, min_samples_split=15, n_estimators=105;, score=0.815 total time=   4.4s
# [CV 5/5] END max_features=250, min_samples_leaf=50, min_samples_split=15, n_estimators=105;, score=0.747 total time=   3.9s
# [CV 1/5] END max_features=250, min_samples_leaf=25, min_samples_split=15, n_estimators=100;, score=0.703 total time=   4.2s
# [CV 2/5] END max_features=250, min_samples_leaf=25, min_samples_split=15, n_estimators=100;, score=0.852 total time=   4.7s
# [CV 3/5] END max_features=250, min_samples_leaf=25, min_samples_split=15, n_estimators=100;, score=0.769 total time=   4.4s
# [CV 4/5] END max_features=250, min_samples_leaf=25, min_samples_split=15, n_estimators=100;, score=0.834 total time=   4.4s
# [CV 5/5] END max_features=250, min_samples_leaf=25, min_samples_split=15, n_estimators=100;, score=0.746 total time=   4.3s
# [CV 1/5] END max_features=50, min_samples_leaf=30, min_samples_split=25, n_estimators=95;, score=0.704 total time=   2.5s
# [CV 2/5] END max_features=50, min_samples_leaf=30, min_samples_split=25, n_estimators=95;, score=0.833 total time=   2.6s
# [CV 3/5] END max_features=50, min_samples_leaf=30, min_samples_split=25, n_estimators=95;, score=0.765 total time=   2.6s
# [CV 4/5] END max_features=50, min_samples_leaf=30, min_samples_split=25, n_estimators=95;, score=0.832 total time=   2.7s
# [CV 5/5] END max_features=50, min_samples_leaf=30, min_samples_split=25, n_estimators=95;, score=0.746 total time=   2.6s
# [CV 1/5] END max_features=400, min_samples_leaf=20, min_samples_split=35, n_estimators=50;, score=0.704 total time=   2.2s
# [CV 2/5] END max_features=400, min_samples_leaf=20, min_samples_split=35, n_estimators=50;, score=0.852 total time=   2.3s
# [CV 3/5] END max_features=400, min_samples_leaf=20, min_samples_split=35, n_estimators=50;, score=0.767 total time=   2.2s
# [CV 4/5] END max_features=400, min_samples_leaf=20, min_samples_split=35, n_estimators=50;, score=0.815 total time=   2.3s
# [CV 5/5] END max_features=400, min_samples_leaf=20, min_samples_split=35, n_estimators=50;, score=0.751 total time=   2.2s
# [CV 1/5] END max_features=300, min_samples_leaf=20, min_samples_split=35, n_estimators=85;, score=0.703 total time=   3.7s
# [CV 2/5] END max_features=300, min_samples_leaf=20, min_samples_split=35, n_estimators=85;, score=0.850 total time=   3.9s
# [CV 3/5] END max_features=300, min_samples_leaf=20, min_samples_split=35, n_estimators=85;, score=0.768 total time=   3.8s
# [CV 4/5] END max_features=300, min_samples_leaf=20, min_samples_split=35, n_estimators=85;, score=0.837 total time=   3.9s
# [CV 5/5] END max_features=300, min_samples_leaf=20, min_samples_split=35, n_estimators=85;, score=0.752 total time=   3.8s
# [CV 1/5] END max_features=250, min_samples_leaf=25, min_samples_split=15, n_estimators=85;, score=0.702 total time=   3.5s
# [CV 2/5] END max_features=250, min_samples_leaf=25, min_samples_split=15, n_estimators=85;, score=0.851 total time=   3.7s
# [CV 3/5] END max_features=250, min_samples_leaf=25, min_samples_split=15, n_estimators=85;, score=0.765 total time=   3.7s
# [CV 4/5] END max_features=250, min_samples_leaf=25, min_samples_split=15, n_estimators=85;, score=0.839 total time=   3.8s
# [CV 5/5] END max_features=250, min_samples_leaf=25, min_samples_split=15, n_estimators=85;, score=0.752 total time=   3.6s
# [CV 1/5] END max_features=350, min_samples_leaf=45, min_samples_split=35, n_estimators=55;, score=0.697 total time=   1.9s
# [CV 2/5] END max_features=350, min_samples_leaf=45, min_samples_split=35, n_estimators=55;, score=0.842 total time=   2.0s
# [CV 3/5] END max_features=350, min_samples_leaf=45, min_samples_split=35, n_estimators=55;, score=0.766 total time=   1.9s
# [CV 4/5] END max_features=350, min_samples_leaf=45, min_samples_split=35, n_estimators=55;, score=0.804 total time=   2.1s
# [CV 5/5] END max_features=350, min_samples_leaf=45, min_samples_split=35, n_estimators=55;, score=0.743 total time=   2.1s
# [CV 1/5] END max_features=400, min_samples_leaf=25, min_samples_split=15, n_estimators=90;, score=0.703 total time=   3.7s
# [CV 2/5] END max_features=400, min_samples_leaf=25, min_samples_split=15, n_estimators=90;, score=0.852 total time=   3.8s
# [CV 3/5] END max_features=400, min_samples_leaf=25, min_samples_split=15, n_estimators=90;, score=0.767 total time=   3.9s
# [CV 4/5] END max_features=400, min_samples_leaf=25, min_samples_split=15, n_estimators=90;, score=0.838 total time=   3.9s
# [CV 5/5] END max_features=400, min_samples_leaf=25, min_samples_split=15, n_estimators=90;, score=0.747 total time=   3.9s
# [CV 1/5] END max_features=250, min_samples_leaf=25, min_samples_split=35, n_estimators=55;, score=0.702 total time=   2.2s
# [CV 2/5] END max_features=250, min_samples_leaf=25, min_samples_split=35, n_estimators=55;, score=0.855 total time=   2.3s
# [CV 3/5] END max_features=250, min_samples_leaf=25, min_samples_split=35, n_estimators=55;, score=0.769 total time=   2.3s
# [CV 4/5] END max_features=250, min_samples_leaf=25, min_samples_split=35, n_estimators=55;, score=0.824 total time=   2.4s
# [CV 5/5] END max_features=250, min_samples_leaf=25, min_samples_split=35, n_estimators=55;, score=0.740 total time=   2.3s
# [CV 1/5] END max_features=350, min_samples_leaf=40, min_samples_split=20, n_estimators=60;, score=0.701 total time=   2.2s
# [CV 2/5] END max_features=350, min_samples_leaf=40, min_samples_split=20, n_estimators=60;, score=0.839 total time=   2.3s
# [CV 3/5] END max_features=350, min_samples_leaf=40, min_samples_split=20, n_estimators=60;, score=0.762 total time=   2.2s
# [CV 4/5] END max_features=350, min_samples_leaf=40, min_samples_split=20, n_estimators=60;, score=0.828 total time=   2.3s
# [CV 5/5] END max_features=350, min_samples_leaf=40, min_samples_split=20, n_estimators=60;, score=0.746 total time=   2.2s
# [CV 1/5] END max_features=250, min_samples_leaf=35, min_samples_split=15, n_estimators=95;, score=0.699 total time=   3.6s
# [CV 2/5] END max_features=250, min_samples_leaf=35, min_samples_split=15, n_estimators=95;, score=0.848 total time=   3.7s
# [CV 3/5] END max_features=250, min_samples_leaf=35, min_samples_split=15, n_estimators=95;, score=0.762 total time=   3.6s
# [CV 4/5] END max_features=250, min_samples_leaf=35, min_samples_split=15, n_estimators=95;, score=0.821 total time=   3.7s
# [CV 5/5] END max_features=250, min_samples_leaf=35, min_samples_split=15, n_estimators=95;, score=0.743 total time=   3.7s
# [CV 1/5] END max_features=50, min_samples_leaf=30, min_samples_split=15, n_estimators=125;, score=0.704 total time=   3.5s
# [CV 2/5] END max_features=50, min_samples_leaf=30, min_samples_split=15, n_estimators=125;, score=0.838 total time=   3.5s
# [CV 3/5] END max_features=50, min_samples_leaf=30, min_samples_split=15, n_estimators=125;, score=0.762 total time=   3.3s
# [CV 4/5] END max_features=50, min_samples_leaf=30, min_samples_split=15, n_estimators=125;, score=0.832 total time=   3.4s
# [CV 5/5] END max_features=50, min_samples_leaf=30, min_samples_split=15, n_estimators=125;, score=0.747 total time=   3.4s
# [CV 1/5] END max_features=50, min_samples_leaf=35, min_samples_split=25, n_estimators=100;, score=0.698 total time=   2.5s
# [CV 2/5] END max_features=50, min_samples_leaf=35, min_samples_split=25, n_estimators=100;, score=0.835 total time=   2.6s
# [CV 3/5] END max_features=50, min_samples_leaf=35, min_samples_split=25, n_estimators=100;, score=0.756 total time=   2.5s
# [CV 4/5] END max_features=50, min_samples_leaf=35, min_samples_split=25, n_estimators=100;, score=0.826 total time=   2.7s
# [CV 5/5] END max_features=50, min_samples_leaf=35, min_samples_split=25, n_estimators=100;, score=0.750 total time=   2.6s
# [CV 1/5] END max_features=300, min_samples_leaf=40, min_samples_split=25, n_estimators=65;, score=0.699 total time=   2.4s
# [CV 2/5] END max_features=300, min_samples_leaf=40, min_samples_split=25, n_estimators=65;, score=0.838 total time=   2.4s
# [CV 3/5] END max_features=300, min_samples_leaf=40, min_samples_split=25, n_estimators=65;, score=0.764 total time=   2.4s
# [CV 4/5] END max_features=300, min_samples_leaf=40, min_samples_split=25, n_estimators=65;, score=0.826 total time=   2.4s
# [CV 5/5] END max_features=300, min_samples_leaf=40, min_samples_split=25, n_estimators=65;, score=0.747 total time=   2.4s
# [CV 1/5] END max_features=250, min_samples_leaf=30, min_samples_split=20, n_estimators=90;, score=0.702 total time=   3.5s
# [CV 2/5] END max_features=250, min_samples_leaf=30, min_samples_split=20, n_estimators=90;, score=0.846 total time=   3.7s
# [CV 3/5] END max_features=250, min_samples_leaf=30, min_samples_split=20, n_estimators=90;, score=0.768 total time=   3.6s
# [CV 4/5] END max_features=250, min_samples_leaf=30, min_samples_split=20, n_estimators=90;, score=0.828 total time=   3.8s
# [CV 5/5] END max_features=250, min_samples_leaf=30, min_samples_split=20, n_estimators=90;, score=0.743 total time=   3.7s
# [CV 1/5] END max_features=150, min_samples_leaf=50, min_samples_split=15, n_estimators=55;, score=0.697 total time=   1.9s
# [CV 2/5] END max_features=150, min_samples_leaf=50, min_samples_split=15, n_estimators=55;, score=0.831 total time=   1.9s
# [CV 3/5] END max_features=150, min_samples_leaf=50, min_samples_split=15, n_estimators=55;, score=0.770 total time=   1.9s
# [CV 4/5] END max_features=150, min_samples_leaf=50, min_samples_split=15, n_estimators=55;, score=0.824 total time=   2.0s
# [CV 5/5] END max_features=150, min_samples_leaf=50, min_samples_split=15, n_estimators=55;, score=0.742 total time=   1.9s
# [CV 1/5] END max_features=150, min_samples_leaf=40, min_samples_split=30, n_estimators=90;, score=0.699 total time=   3.3s
# [CV 2/5] END max_features=150, min_samples_leaf=40, min_samples_split=30, n_estimators=90;, score=0.835 total time=   3.4s
# [CV 3/5] END max_features=150, min_samples_leaf=40, min_samples_split=30, n_estimators=90;, score=0.760 total time=   3.3s
# [CV 4/5] END max_features=150, min_samples_leaf=40, min_samples_split=30, n_estimators=90;, score=0.825 total time=   3.4s
# [CV 5/5] END max_features=150, min_samples_leaf=40, min_samples_split=30, n_estimators=90;, score=0.744 total time=   3.3s
# [CV 1/5] END max_features=250, min_samples_leaf=35, min_samples_split=25, n_estimators=125;, score=0.697 total time=   4.7s
# [CV 2/5] END max_features=250, min_samples_leaf=35, min_samples_split=25, n_estimators=125;, score=0.850 total time=   4.9s
# [CV 3/5] END max_features=250, min_samples_leaf=35, min_samples_split=25, n_estimators=125;, score=0.763 total time=   4.9s
# [CV 4/5] END max_features=250, min_samples_leaf=35, min_samples_split=25, n_estimators=125;, score=0.822 total time=   4.9s
# [CV 5/5] END max_features=250, min_samples_leaf=35, min_samples_split=25, n_estimators=125;, score=0.744 total time=   4.9s
# [CV 1/5] END max_features=400, min_samples_leaf=45, min_samples_split=25, n_estimators=55;, score=0.697 total time=   2.0s
# [CV 2/5] END max_features=400, min_samples_leaf=45, min_samples_split=25, n_estimators=55;, score=0.842 total time=   2.0s
# [CV 3/5] END max_features=400, min_samples_leaf=45, min_samples_split=25, n_estimators=55;, score=0.766 total time=   2.0s
# [CV 4/5] END max_features=400, min_samples_leaf=45, min_samples_split=25, n_estimators=55;, score=0.804 total time=   2.0s
# [CV 5/5] END max_features=400, min_samples_leaf=45, min_samples_split=25, n_estimators=55;, score=0.743 total time=   2.0s
# [CV 1/5] END max_features=150, min_samples_leaf=50, min_samples_split=30, n_estimators=65;, score=0.696 total time=   2.2s
# [CV 2/5] END max_features=150, min_samples_leaf=50, min_samples_split=30, n_estimators=65;, score=0.830 total time=   2.3s
# [CV 3/5] END max_features=150, min_samples_leaf=50, min_samples_split=30, n_estimators=65;, score=0.769 total time=   2.2s
# [CV 4/5] END max_features=150, min_samples_leaf=50, min_samples_split=30, n_estimators=65;, score=0.820 total time=   2.4s
# [CV 5/5] END max_features=150, min_samples_leaf=50, min_samples_split=30, n_estimators=65;, score=0.744 total time=   2.7s
# [CV 1/5] END max_features=100, min_samples_leaf=50, min_samples_split=35, n_estimators=110;, score=0.696 total time=   3.9s
# [CV 2/5] END max_features=100, min_samples_leaf=50, min_samples_split=35, n_estimators=110;, score=0.833 total time=   4.3s
# [CV 3/5] END max_features=100, min_samples_leaf=50, min_samples_split=35, n_estimators=110;, score=0.765 total time=   4.2s
# [CV 4/5] END max_features=100, min_samples_leaf=50, min_samples_split=35, n_estimators=110;, score=0.814 total time=   4.1s
# [CV 5/5] END max_features=100, min_samples_leaf=50, min_samples_split=35, n_estimators=110;, score=0.747 total time=   3.9s
# [CV 1/5] END max_features=400, min_samples_leaf=45, min_samples_split=30, n_estimators=65;, score=0.701 total time=   2.3s
# [CV 2/5] END max_features=400, min_samples_leaf=45, min_samples_split=30, n_estimators=65;, score=0.842 total time=   2.3s
# [CV 3/5] END max_features=400, min_samples_leaf=45, min_samples_split=30, n_estimators=65;, score=0.769 total time=   2.3s
# [CV 4/5] END max_features=400, min_samples_leaf=45, min_samples_split=30, n_estimators=65;, score=0.810 total time=   2.4s
# [CV 5/5] END max_features=400, min_samples_leaf=45, min_samples_split=30, n_estimators=65;, score=0.745 total time=   2.3s
# [CV 1/5] END max_features=50, min_samples_leaf=40, min_samples_split=35, n_estimators=95;, score=0.696 total time=   2.3s
# [CV 2/5] END max_features=50, min_samples_leaf=40, min_samples_split=35, n_estimators=95;, score=0.831 total time=   2.4s
# [CV 3/5] END max_features=50, min_samples_leaf=40, min_samples_split=35, n_estimators=95;, score=0.756 total time=   2.3s
# [CV 4/5] END max_features=50, min_samples_leaf=40, min_samples_split=35, n_estimators=95;, score=0.819 total time=   2.4s
# [CV 5/5] END max_features=50, min_samples_leaf=40, min_samples_split=35, n_estimators=95;, score=0.746 total time=   2.3s
# [CV 1/5] END max_features=100, min_samples_leaf=25, min_samples_split=15, n_estimators=110;, score=0.704 total time=   4.5s
# [CV 2/5] END max_features=100, min_samples_leaf=25, min_samples_split=15, n_estimators=110;, score=0.854 total time=   4.7s
# [CV 3/5] END max_features=100, min_samples_leaf=25, min_samples_split=15, n_estimators=110;, score=0.768 total time=   4.6s
# [CV 4/5] END max_features=100, min_samples_leaf=25, min_samples_split=15, n_estimators=110;, score=0.834 total time=   4.8s
# [CV 5/5] END max_features=100, min_samples_leaf=25, min_samples_split=15, n_estimators=110;, score=0.745 total time=   4.7s
# [CV 1/5] END max_features=400, min_samples_leaf=40, min_samples_split=25, n_estimators=100;, score=0.699 total time=   3.6s
# [CV 2/5] END max_features=400, min_samples_leaf=40, min_samples_split=25, n_estimators=100;, score=0.838 total time=   3.7s
# [CV 3/5] END max_features=400, min_samples_leaf=40, min_samples_split=25, n_estimators=100;, score=0.763 total time=   3.7s
# [CV 4/5] END max_features=400, min_samples_leaf=40, min_samples_split=25, n_estimators=100;, score=0.826 total time=   3.8s
# [CV 5/5] END max_features=400, min_samples_leaf=40, min_samples_split=25, n_estimators=100;, score=0.746 total time=   3.7s
# [CV 1/5] END max_features=150, min_samples_leaf=20, min_samples_split=25, n_estimators=60;, score=0.704 total time=   2.6s
# [CV 2/5] END max_features=150, min_samples_leaf=20, min_samples_split=25, n_estimators=60;, score=0.852 total time=   2.7s
# [CV 3/5] END max_features=150, min_samples_leaf=20, min_samples_split=25, n_estimators=60;, score=0.770 total time=   2.7s
# [CV 4/5] END max_features=150, min_samples_leaf=20, min_samples_split=25, n_estimators=60;, score=0.821 total time=   2.7s
# [CV 5/5] END max_features=150, min_samples_leaf=20, min_samples_split=25, n_estimators=60;, score=0.754 total time=   2.6s
# [CV 1/5] END max_features=400, min_samples_leaf=20, min_samples_split=25, n_estimators=50;, score=0.704 total time=   2.1s
# [CV 2/5] END max_features=400, min_samples_leaf=20, min_samples_split=25, n_estimators=50;, score=0.852 total time=   2.2s
# [CV 3/5] END max_features=400, min_samples_leaf=20, min_samples_split=25, n_estimators=50;, score=0.767 total time=   2.2s
# [CV 4/5] END max_features=400, min_samples_leaf=20, min_samples_split=25, n_estimators=50;, score=0.815 total time=   2.3s
# [CV 5/5] END max_features=400, min_samples_leaf=20, min_samples_split=25, n_estimators=50;, score=0.751 total time=   2.2s
# [CV 1/5] END max_features=200, min_samples_leaf=45, min_samples_split=15, n_estimators=115;, score=0.703 total time=   4.1s
# [CV 2/5] END max_features=200, min_samples_leaf=45, min_samples_split=15, n_estimators=115;, score=0.843 total time=   4.2s
# [CV 3/5] END max_features=200, min_samples_leaf=45, min_samples_split=15, n_estimators=115;, score=0.765 total time=   4.2s
# [CV 4/5] END max_features=200, min_samples_leaf=45, min_samples_split=15, n_estimators=115;, score=0.810 total time=   4.3s
# [CV 5/5] END max_features=200, min_samples_leaf=45, min_samples_split=15, n_estimators=115;, score=0.746 total time=   4.3s
# [CV 1/5] END max_features=200, min_samples_leaf=25, min_samples_split=20, n_estimators=50;, score=0.705 total time=   2.0s
# [CV 2/5] END max_features=200, min_samples_leaf=25, min_samples_split=20, n_estimators=50;, score=0.853 total time=   2.1s
# [CV 3/5] END max_features=200, min_samples_leaf=25, min_samples_split=20, n_estimators=50;, score=0.768 total time=   2.1s
# [CV 4/5] END max_features=200, min_samples_leaf=25, min_samples_split=20, n_estimators=50;, score=0.821 total time=   2.1s
# [CV 5/5] END max_features=200, min_samples_leaf=25, min_samples_split=20, n_estimators=50;, score=0.748 total time=   2.1s
# [CV 1/5] END max_features=250, min_samples_leaf=50, min_samples_split=30, n_estimators=125;, score=0.693 total time=   4.4s
# [CV 2/5] END max_features=250, min_samples_leaf=50, min_samples_split=30, n_estimators=125;, score=0.834 total time=   4.4s
# [CV 3/5] END max_features=250, min_samples_leaf=50, min_samples_split=30, n_estimators=125;, score=0.762 total time=   4.4s
# [CV 4/5] END max_features=250, min_samples_leaf=50, min_samples_split=30, n_estimators=125;, score=0.818 total time=   4.5s
# [CV 5/5] END max_features=250, min_samples_leaf=50, min_samples_split=30, n_estimators=125;, score=0.746 total time=   4.4s
# [CV 1/5] END max_features=100, min_samples_leaf=50, min_samples_split=15, n_estimators=105;, score=0.695 total time=   3.6s
# [CV 2/5] END max_features=100, min_samples_leaf=50, min_samples_split=15, n_estimators=105;, score=0.832 total time=   3.7s
# [CV 3/5] END max_features=100, min_samples_leaf=50, min_samples_split=15, n_estimators=105;, score=0.764 total time=   3.7s
# [CV 4/5] END max_features=100, min_samples_leaf=50, min_samples_split=15, n_estimators=105;, score=0.815 total time=   3.7s
# [CV 5/5] END max_features=100, min_samples_leaf=50, min_samples_split=15, n_estimators=105;, score=0.747 total time=   3.7s
# [CV 1/5] END max_features=300, min_samples_leaf=35, min_samples_split=20, n_estimators=70;, score=0.700 total time=   2.6s
# [CV 2/5] END max_features=300, min_samples_leaf=35, min_samples_split=20, n_estimators=70;, score=0.843 total time=   2.7s
# [CV 3/5] END max_features=300, min_samples_leaf=35, min_samples_split=20, n_estimators=70;, score=0.759 total time=   2.7s
# [CV 4/5] END max_features=300, min_samples_leaf=35, min_samples_split=20, n_estimators=70;, score=0.826 total time=   2.8s
# [CV 5/5] END max_features=300, min_samples_leaf=35, min_samples_split=20, n_estimators=70;, score=0.747 total time=   2.7s
# [CV 1/5] END max_features=300, min_samples_leaf=50, min_samples_split=25, n_estimators=95;, score=0.696 total time=   3.3s
# [CV 2/5] END max_features=300, min_samples_leaf=50, min_samples_split=25, n_estimators=95;, score=0.832 total time=   3.3s
# [CV 3/5] END max_features=300, min_samples_leaf=50, min_samples_split=25, n_estimators=95;, score=0.764 total time=   3.4s
# [CV 4/5] END max_features=300, min_samples_leaf=50, min_samples_split=25, n_estimators=95;, score=0.815 total time=   3.4s
# [CV 5/5] END max_features=300, min_samples_leaf=50, min_samples_split=25, n_estimators=95;, score=0.746 total time=   3.4s
# [CV 1/5] END max_features=350, min_samples_leaf=40, min_samples_split=35, n_estimators=85;, score=0.700 total time=   3.1s
# [CV 2/5] END max_features=350, min_samples_leaf=40, min_samples_split=35, n_estimators=85;, score=0.836 total time=   3.1s
# [CV 3/5] END max_features=350, min_samples_leaf=40, min_samples_split=35, n_estimators=85;, score=0.759 total time=   3.1s
# [CV 4/5] END max_features=350, min_samples_leaf=40, min_samples_split=35, n_estimators=85;, score=0.825 total time=   3.3s
# [CV 5/5] END max_features=350, min_samples_leaf=40, min_samples_split=35, n_estimators=85;, score=0.745 total time=   3.2s
# [CV 1/5] END max_features=200, min_samples_leaf=45, min_samples_split=35, n_estimators=65;, score=0.701 total time=   2.3s
# [CV 2/5] END max_features=200, min_samples_leaf=45, min_samples_split=35, n_estimators=65;, score=0.842 total time=   2.4s
# [CV 3/5] END max_features=200, min_samples_leaf=45, min_samples_split=35, n_estimators=65;, score=0.769 total time=   2.3s
# [CV 4/5] END max_features=200, min_samples_leaf=45, min_samples_split=35, n_estimators=65;, score=0.810 total time=   2.4s
# [CV 5/5] END max_features=200, min_samples_leaf=45, min_samples_split=35, n_estimators=65;, score=0.745 total time=   2.4s
# [CV 1/5] END max_features=150, min_samples_leaf=25, min_samples_split=30, n_estimators=65;, score=0.703 total time=   2.7s
# [CV 2/5] END max_features=150, min_samples_leaf=25, min_samples_split=30, n_estimators=65;, score=0.852 total time=   2.8s
# [CV 3/5] END max_features=150, min_samples_leaf=25, min_samples_split=30, n_estimators=65;, score=0.767 total time=   2.7s
# [CV 4/5] END max_features=150, min_samples_leaf=25, min_samples_split=30, n_estimators=65;, score=0.832 total time=   2.8s
# [CV 5/5] END max_features=150, min_samples_leaf=25, min_samples_split=30, n_estimators=65;, score=0.746 total time=   2.7s
# [CV 1/5] END max_features=250, min_samples_leaf=20, min_samples_split=25, n_estimators=100;, score=0.706 total time=   4.5s
# [CV 2/5] END max_features=250, min_samples_leaf=20, min_samples_split=25, n_estimators=100;, score=0.854 total time=   4.5s
# [CV 3/5] END max_features=250, min_samples_leaf=20, min_samples_split=25, n_estimators=100;, score=0.767 total time=   4.5s
# [CV 4/5] END max_features=250, min_samples_leaf=20, min_samples_split=25, n_estimators=100;, score=0.833 total time=   5.0s
# [CV 5/5] END max_features=250, min_samples_leaf=20, min_samples_split=25, n_estimators=100;, score=0.756 total time=   4.5s
# [CV 1/5] END max_features=200, min_samples_leaf=35, min_samples_split=35, n_estimators=80;, score=0.699 total time=   3.0s
# [CV 2/5] END max_features=200, min_samples_leaf=35, min_samples_split=35, n_estimators=80;, score=0.847 total time=   3.1s
# [CV 3/5] END max_features=200, min_samples_leaf=35, min_samples_split=35, n_estimators=80;, score=0.758 total time=   3.1s
# [CV 4/5] END max_features=200, min_samples_leaf=35, min_samples_split=35, n_estimators=80;, score=0.823 total time=   3.6s
# [CV 5/5] END max_features=200, min_samples_leaf=35, min_samples_split=35, n_estimators=80;, score=0.744 total time=   3.2s
# [CV 1/5] END max_features=350, min_samples_leaf=35, min_samples_split=15, n_estimators=75;, score=0.700 total time=   3.0s
# [CV 2/5] END max_features=350, min_samples_leaf=35, min_samples_split=15, n_estimators=75;, score=0.845 total time=   3.2s
# [CV 3/5] END max_features=350, min_samples_leaf=35, min_samples_split=15, n_estimators=75;, score=0.760 total time=   2.9s
# [CV 4/5] END max_features=350, min_samples_leaf=35, min_samples_split=15, n_estimators=75;, score=0.821 total time=   3.0s
# [CV 5/5] END max_features=350, min_samples_leaf=35, min_samples_split=15, n_estimators=75;, score=0.743 total time=   2.9s
# [CV 1/5] END max_features=200, min_samples_leaf=45, min_samples_split=20, n_estimators=100;, score=0.702 total time=   3.6s
# [CV 2/5] END max_features=200, min_samples_leaf=45, min_samples_split=20, n_estimators=100;, score=0.843 total time=   3.7s
# [CV 3/5] END max_features=200, min_samples_leaf=45, min_samples_split=20, n_estimators=100;, score=0.766 total time=   3.8s
# [CV 4/5] END max_features=200, min_samples_leaf=45, min_samples_split=20, n_estimators=100;, score=0.807 total time=   4.0s
# [CV 5/5] END max_features=200, min_samples_leaf=45, min_samples_split=20, n_estimators=100;, score=0.747 total time=   3.8s
# [CV 1/5] END max_features=150, min_samples_leaf=40, min_samples_split=20, n_estimators=105;, score=0.700 total time=   4.1s
# [CV 2/5] END max_features=150, min_samples_leaf=40, min_samples_split=20, n_estimators=105;, score=0.838 total time=   4.3s
# [CV 3/5] END max_features=150, min_samples_leaf=40, min_samples_split=20, n_estimators=105;, score=0.764 total time=   4.0s
# [CV 4/5] END max_features=150, min_samples_leaf=40, min_samples_split=20, n_estimators=105;, score=0.829 total time=   4.3s
# [CV 5/5] END max_features=150, min_samples_leaf=40, min_samples_split=20, n_estimators=105;, score=0.746 total time=   4.5s
# [CV 1/5] END max_features=350, min_samples_leaf=25, min_samples_split=30, n_estimators=60;, score=0.702 total time=   2.7s
# [CV 2/5] END max_features=350, min_samples_leaf=25, min_samples_split=30, n_estimators=60;, score=0.854 total time=   2.9s
# [CV 3/5] END max_features=350, min_samples_leaf=25, min_samples_split=30, n_estimators=60;, score=0.770 total time=   2.7s
# [CV 4/5] END max_features=350, min_samples_leaf=25, min_samples_split=30, n_estimators=60;, score=0.831 total time=   2.9s
# [CV 5/5] END max_features=350, min_samples_leaf=25, min_samples_split=30, n_estimators=60;, score=0.746 total time=   2.9s
# [CV 1/5] END max_features=300, min_samples_leaf=25, min_samples_split=25, n_estimators=80;, score=0.702 total time=   3.9s
# [CV 2/5] END max_features=300, min_samples_leaf=25, min_samples_split=25, n_estimators=80;, score=0.852 total time=   3.8s
# [CV 3/5] END max_features=300, min_samples_leaf=25, min_samples_split=25, n_estimators=80;, score=0.765 total time=   3.7s
# [CV 4/5] END max_features=300, min_samples_leaf=25, min_samples_split=25, n_estimators=80;, score=0.838 total time=   3.8s
# [CV 5/5] END max_features=300, min_samples_leaf=25, min_samples_split=25, n_estimators=80;, score=0.749 total time=   3.8s

# %%
print(f"time elapsed: {t2-t1} seconds or {int((t2-t1)//60)} minutes and {int((t2-t1)-(t2-t1)//60*60)} seconds")
# Out:
# time elapsed: 1658.8042409420013 seconds or 27 minutes and 38 seconds

# %%
print(accuracy_score(test_label,clf.predict(X_test_scaled)))
# Out:
# 0.9258333333333333

# %%
from sklearn.metrics import classification_report, roc_curve, RocCurveDisplay, roc_auc_score, auc

# %%
print(classification_report(test_label,clf.predict(X_test_scaled), target_names=["Queen", "Queenless"]))
# Out:
#               precision    recall  f1-score   support
#
#        Queen       0.92      0.94      0.93      3000
#    Queenless       0.93      0.92      0.93      3000
#
#     accuracy                           0.93      6000
#    macro avg       0.93      0.93      0.93      6000
# weighted avg       0.93      0.93      0.93      6000

# %%
roc_curve(test_label,clf.predict(X_test_scaled))
# Out:
# (array([0.   , 0.064, 1.   ]),
#  array([0.        , 0.91566667, 1.        ]),
#  array([inf,  1.,  0.]))

# %%
import matplotlib.pyplot as plt

# %%
RocCurveDisplay.from_predictions(
    np.array(test_label.values).ravel(),
    np.array(clf.predict(X_test_scaled)).ravel(),
    name="micro-average OvR",
    color="darkorange",

)
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Micro-averaged One-vs-Rest\nReceiver Operating Characteristic")
plt.legend()
plt.show()

# %%
y_pred_proba = clf.predict_proba(X_test_scaled)[::,1]
fpr, tpr, _ = roc_curve(test_label,  y_pred_proba)
auc = roc_auc_score(test_label, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
from sklearn.metrics import classification_report, roc_curve, RocCurveDisplay, roc_auc_score, auc

fpr, tpr, thresholds = roc_curve(test_label, clf.predict_proba(X_test_scaled)[:, 1])

auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label="ROC curve (area = {0:.2f})".format(auc))
plt.plot([0, 1], [0, 1], linestyle="dashed")
# plt.title("FFT 1D with XGBoost roc_curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.savefig("FFT 1D with XGBoost roc_curve.png")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# %%
import seaborn as sns

cf_mat = confusion_matrix(test_label, clf.predict(X_test_scaled))
df_cm = pd.DataFrame(cf_mat, index = [i for i in ['Queen', 'Queenless']],
                  columns = [i for i in ['Queen', 'Queenless']])
df_cm_normed = df_cm/df_cm.sum()
plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=True, fmt="", )
# Out:
# <Axes: >

# %%
df_cm_normed = df_cm/df_cm.sum()
plt.figure(figsize = (10,7))
sns.heatmap(df_cm_normed, annot=True, fmt=".3f", )
# Out:
# <Axes: >
